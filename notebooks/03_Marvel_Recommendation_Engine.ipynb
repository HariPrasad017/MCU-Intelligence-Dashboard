# %% [markdown]
# ### Import Libraries

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("C:\\Users\\ACER\\Documents\\Marvel Cinematic Universe Intelligence Dashboard & Success Prediction System\\notebooks\\Marvel_MCU_Final_Analytics_Dataset_Power_BI.csv")
df.head()
# Out:
#                                title   type  release_year  mcu_phase_number  \
# 0                           iron man  Movie          2008                 1
# 1                the incredible hulk  Movie          2008                 1
# 2                         iron man 2  Movie          2010                 1
# 3                               thor  Movie          2011                 1
# 4  captain america the first avenger  Movie          2011                 1
#
#    imdb_rating  rt_tomato_meter  rt_audience_score  production_budget  \
# 0          7.9               94                 91          140000000
# 1          6.6               67                 70          140000000
# 2          6.9               72                 71          200000000
# 3          7.0               77                 76          150000000
# 4          6.9               79                 75          140000000
#
#    domestic_box_office  international_box_office  ...  decade  \
# ...

# %% [markdown]
# Column Creation

# %%
df["content"] = (

    df["genres"]

    + " "

    + df["director"]

    + " "

    + df["success_category"]

)

# %% [markdown]
# ### TF-IDF

# %%
tfidf = TfidfVectorizer(
    stop_words="english"
)

tfidf_matrix = tfidf.fit_transform(
    df["content"]
)

# %% [markdown]
# ### Cosine Similarity

# %%
cosine_sim = cosine_similarity(
    tfidf_matrix,
    tfidf_matrix
)

# %% [markdown]
# Movie Index

# %%
indices = pd.Series(
    df.index,
    index=df["title"]
).drop_duplicates()

# %% [markdown]
# ### Recommendation Function

# %%
def recommend_movies(movie_name):

    idx = indices[movie_name]

    similarity_scores = list(
        enumerate(
            cosine_sim[idx]
        )
    )

    similarity_scores = sorted(
        similarity_scores,
        key=lambda x:x[1],
        reverse=True
    )

    similarity_scores = similarity_scores[1:6]

    movie_indices = [
        i[0]
        for i in similarity_scores
    ]

    return df[
        ["title"]
    ].iloc[movie_indices]

# %% [markdown]
# ### Test

# %%
# Redefine recommend_movies to be case-insensitive and then call it
def recommend_movies(movie_name):
    key = movie_name.strip().lower()
    lower_indices = pd.Series(indices.values, index=indices.index.str.lower()).drop_duplicates()
    if key not in lower_indices.index:
        raise KeyError(f"Movie '{movie_name}' not found.")
    idx = int(lower_indices[key])

    similarity_scores = list(enumerate(cosine_sim[idx]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similarity_scores = similarity_scores[1:6]
    movie_indices = [i[0] for i in similarity_scores]
    return df[["title"]].iloc[movie_indices]

recommend_movies("Avengers Endgame")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ACER\Documents\Marvel Cinematic Universe Intelligence Dashboard & Success Prediction System\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
